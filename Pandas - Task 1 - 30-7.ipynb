# %%
import pandas as pd

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df = pd.read_csv(r"C:\Users\DJParni\iNeuron\Dataset\AgentLogingReport.csv")

# %%
df2 = pd.read_csv(r"C:\Users\DJParni\iNeuron\Dataset\AgentPerformance.csv")

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2[ ['Date', 'Average Rating' ]]
# Out:
#            Date  Average Rating
# 0     7/30/2022            4.11
# 1     7/30/2022            3.14
# 2     7/30/2022            4.55
# 3     7/30/2022            4.71
# 4     7/30/2022            3.67
# ...         ...             ...
# 2155   7/1/2022            0.00
# 2156   7/1/2022            0.00
# 2157   7/1/2022            0.00
# 2158   7/1/2022            0.00
# 2159   7/1/2022            0.00
#
# [2160 rows x 2 columns]

# %%
df2.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df2['New Date'] = pd.to_datetime(df2['Date'])

# %% [markdown]
# ##

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2 = pd.read_csv(r"C:\Users\DJParni\iNeuron\Dataset\AgentPerformance.csv")

# %% [markdown]
# df2

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2['New Date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
agents = df['Agent'].unique()

# %%
agents
# Out:
# array(['Shivananda Sonwane', 'Khushboo Priya', 'Nandani Gupta',
#        'Hrisikesh Neogi', 'Mukesh', 'Sowmiya Sivakumar', 'Manjunatha A',
#        'Harikrishnan Shaji', 'Suraj S Bilgi', 'Shivan K', 'Anurag Tiwari',
#        'Ishawant Kumar', 'Shubham Sharma', 'Prerna Singh', 'Nishtha Jain',
#        'Prateek _iot', 'Mithun S', 'Madhulika G', 'Boktiar Ahmed Bappy',
#        'Jawala Prakash', 'Dibyanshu', 'Deepranjan Gupta', 'Jaydeep Dixit',
#        'Ayushi Mishra', 'Mahesh Sarade', 'Muskan Garg',
#        'Chaitra K Hiremath', 'Shiva Srivastava', 'Aditya_iot',
#        'Prabir Kumar Satapathy', 'Sanjeev Kumar', 'Zeeshan',
#        'Rishav Dash', 'Wasim', 'Bharath', 'Ameya Jain', 'Saikumarreddy N',
#        'Aravind', 'Amersh', 'Sudhanshu Kumar', 'Ankitjha', 'Maitry',
#        'Aditya Shinde', 'Hyder Abbas', 'Swati', 'Saurabh Shukla',
#        'Nitin M', 'Ineuron Intelligence', 'Tarun'], dtype=object)

# %%
#11 . list of all agents name 
i = 1
for names in agents:
    print(i , names)
    i += 1
# Out:
# 1 Shivananda Sonwane
# 2 Khushboo Priya
# 3 Nandani Gupta
# 4 Hrisikesh Neogi
# 5 Mukesh
# 6 Sowmiya Sivakumar
# 7 Manjunatha A
# 8 Harikrishnan Shaji
# 9 Suraj S Bilgi
# 10 Shivan K
# 11 Anurag Tiwari
# 12 Ishawant Kumar
# 13 Shubham Sharma
# 14 Prerna Singh
# 15 Nishtha Jain
# 16 Prateek _iot
# 17 Mithun S
# 18 Madhulika G
# 19 Boktiar Ahmed Bappy
# 20 Jawala Prakash
# 21 Dibyanshu
# 22 Deepranjan Gupta
# 23 Jaydeep Dixit
# 24 Ayushi Mishra
# 25 Mahesh Sarade
# 26 Muskan Garg
# 27 Chaitra K Hiremath
# 28 Shiva Srivastava
# 29 Aditya_iot
# 30 Prabir Kumar Satapathy
# 31 Sanjeev Kumar
# 32 Zeeshan
# 33 Rishav Dash
# 34 Wasim
# 35 Bharath
# 36 Ameya Jain
# 37 Saikumarreddy N
# 38 Aravind
# 39 Amersh
# 40 Sudhanshu Kumar
# 41 Ankitjha
# 42 Maitry
# 43 Aditya Shinde
# 44 Hyder Abbas
# 45 Swati
# 46 Saurabh Shukla
# 47 Nitin M
# 48 Ineuron Intelligence
# 49 Tarun

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#a agent name who have average rating between 3.5 to 4 
display(df2[(df2['Average Rating'] > 3.5) & (df2['Average Rating'] < 4.0)][['Agent Name','Average Rating']])
# Out:
#                Agent Name  Average Rating
# 4                  Swati             3.67
# 10           Manjunatha A            3.60
# 76          Prateek _iot             3.75
# 78          Nandani Gupta            3.79
# 80          Jaydeep Dixit            3.95
# ...                   ...             ...
# 1869  Boktiar Ahmed Bappy            3.78
# 1874        Ayushi Mishra            3.80
# 1941       Jawala Prakash            3.80
# 2021        Aditya Shinde            3.54
# 2023     Deepranjan Gupta            3.71
#
# [78 rows x 2 columns]

# %%
#Agent name who have rating lesss then 3.5 
display(df2[(df2['Average Rating'] < 3.5)][['Agent Name','Average Rating']])
# Out:
#               Agent Name  Average Rating
# 1          Nandani Gupta            3.14
# 19      Hitesh Choudhary            0.00
# 20            Sanjeevan             0.00
# 21              Anirudh             0.00
# 22      Shiva Srivastava            0.00
# ...                  ...             ...
# 2155   Sowmiya Sivakumar            0.00
# 2156             Nitin M            0.00
# 2157              Vivek             0.00
# 2158       Ayushi Mishra            0.00
# 2159  Chaitra K Hiremath            0.00
#
# [1474 rows x 2 columns]

# %%
#7 . agent name who have rating more then 4.5 
display(df2[(df2['Average Rating'] > 4.5)][['Agent Name','Average Rating']])
# Out:
#               Agent Name  Average Rating
# 2             Ameya Jain            4.55
# 3          Mahesh Sarade            4.71
# 5                Mukesh             4.62
# 6        Saikumarreddy N            5.00
# 7          Sanjeev Kumar            5.00
# ...                  ...             ...
# 2100      Shubham Sharma            5.00
# 2101       Jaydeep Dixit            4.77
# 2102  Shivananda Sonwane            4.86
# 2103      Khushboo Priya            4.61
# 2104     Hrisikesh Neogi            4.56
#
# [307 rows x 2 columns]

# %%
df2[df2['Agent Name'] == 'Prerna Singh']['Total Feedback'].mean()
# Out:
# 7.833333333333333

# %%
avgFeedback = df2.groupby('Agent Name')['Total Feedback'].mean()

# %%
 #how many feedaback agents have received more then 4.5 average
i = 1
for feedback in avgFeedback:
    if feedback > 4.5:
        print(i , feedback)
        i+=1
print("Total Count = {}".format(i-1))
# Out:
# 1 5.1
# 2 7.6
# 3 7.766666666666667
# 4 10.966666666666667
# 5 8.233333333333333
# 6 10.366666666666667
# 7 10.4
# 8 7.7
# 9 12.233333333333333
# 10 6.733333333333333
# 11 8.333333333333334
# 12 10.166666666666666
# 13 9.633333333333333
# 14 9.366666666666667
# 15 7.2
# 16 11.566666666666666
# 17 8.466666666666667
# 18 12.133333333333333
# 19 10.266666666666667
# 20 8.566666666666666
# 21 7.4
# 22 7.833333333333333
# 23 9.666666666666666
# 24 10.366666666666667
# 25 8.1
# 26 8.766666666666667
# 27 10.0
# 28 4.7
# 29 10.066666666666666
# 30 9.466666666666667
# 31 11.166666666666666
# Total Count = 31

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#Total working days for each agents
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
wrkgdays = df[df['Agent'] == 'Shivananda Sonwane']['Date'].unique()

# %%
wrkgdays
# Out:
# array(['20-Jul-22', '22-Jul-22', '23-Jul-22', '24-Jul-22', '25-Jul-22',
#        '26-Jul-22', '27-Jul-22', '28-Jul-22', '29-Jul-22', '30-Jul-22'],
#       dtype=object)

# %%
occur = df.groupby(['Agent', 'Date']).size()

# %%
print(occur)
# Out:
# Agent          Date
# Aditya Shinde  26-Jul-22    1
# Aditya_iot     20-Jul-22    1
#                21-Jul-22    1
#                22-Jul-22    1
#                25-Jul-22    1
#                            ..
# Zeeshan        24-Jul-22    1
#                25-Jul-22    1
#                27-Jul-22    1
#                28-Jul-22    1
#                29-Jul-22    1
# Length: 337, dtype: int64

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
wrk = df[df['Agent'] == 'Aditya_iot']['Date']

# %%
print(wrk)
# Out:
# 72     29-Jul-22
# 178    28-Jul-22
# 179    28-Jul-22
# 298    27-Jul-22
# 410    26-Jul-22
# 498    25-Jul-22
# 728    22-Jul-22
# 856    21-Jul-22
# 950    20-Jul-22
# Name: Date, dtype: object

# %%
wrk1 = df[df['Agent'] == 'Aditya_iot']['Date'].unique()

# %%
print(wrk1)
# Out:
# ['29-Jul-22' '28-Jul-22' '27-Jul-22' '26-Jul-22' '25-Jul-22' '22-Jul-22'
#  '21-Jul-22' '20-Jul-22']

# %%
i=1
for each in wrk1:
    print(i , each)
    i=i+1
print ("Toal working days := {}".format(i-1))
# Out:
# 1 29-Jul-22
# 2 28-Jul-22
# 3 27-Jul-22
# 4 26-Jul-22
# 5 25-Jul-22
# 6 22-Jul-22
# 7 21-Jul-22
# 8 20-Jul-22
# Toal working days := 8

# %%
occur = df.groupby(['Agent']).size()

# %%
print(occur)
# Out:
# Agent
# Aditya Shinde               1
# Aditya_iot                  9
# Amersh                      4
# Ameya Jain                 10
# Ankitjha                    4
# Anurag Tiwari              37
# Aravind                    10
# Ayushi Mishra              18
# Bharath                     9
# Boktiar Ahmed Bappy        17
# Chaitra K Hiremath         13
# Deepranjan Gupta           58
# Dibyanshu                 208
# Harikrishnan Shaji         23
# Hrisikesh Neogi            37
# Hyder Abbas                 2
# Ineuron Intelligence        1
# Ishawant Kumar             49
# Jawala Prakash             16
# Jaydeep Dixit              11
# Khushboo Priya             18
# Madhulika G                17
# Mahesh Sarade              36
# Maitry                      5
# Manjunatha A                8
# Mithun S                   14
# Mukesh                      3
# Muskan Garg                12
# Nandani Gupta              11
# Nishtha Jain               18
# Nitin M                     1
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['date_d'] = df['Date'].dt.to_period('d')

# %%
ct = df.groupby(['Agent', 'date_d']).size()

# %%
print(ct)
# Out:
# Agent          date_d
# Aditya Shinde  2022-07-26    1
# Aditya_iot     2022-07-20    1
#                2022-07-21    1
#                2022-07-22    1
#                2022-07-25    1
#                             ..
# Zeeshan        2022-07-24    1
#                2022-07-25    1
#                2022-07-27    1
#                2022-07-28    1
#                2022-07-29    1
# Length: 337, dtype: int64

# %%
df1 = df.groupby(df['Date'].dt.date).size().reset_index(name='Count')

# %%
df1
# Out:
#           Date  Count
# 0   2022-07-01      1
# 1   2022-07-20     91
# 2   2022-07-21     73
# 3   2022-07-22    138
# 4   2022-07-23     80
# 5   2022-07-24     69
# 6   2022-07-25     68
# 7   2022-07-26     98
# 8   2022-07-27    130
# 9   2022-07-28     92
# 10  2022-07-29    126
# 11  2022-07-30     34

# %%
print(occur)
# Out:
# Agent
# Aditya Shinde               1
# Aditya_iot                  9
# Amersh                      4
# Ameya Jain                 10
# Ankitjha                    4
# Anurag Tiwari              37
# Aravind                    10
# Ayushi Mishra              18
# Bharath                     9
# Boktiar Ahmed Bappy        17
# Chaitra K Hiremath         13
# Deepranjan Gupta           58
# Dibyanshu                 208
# Harikrishnan Shaji         23
# Hrisikesh Neogi            37
# Hyder Abbas                 2
# Ineuron Intelligence        1
# Ishawant Kumar             49
# Jawala Prakash             16
# Jaydeep Dixit              11
# Khushboo Priya             18
# Madhulika G                17
# Mahesh Sarade              36
# Maitry                      5
# Manjunatha A                8
# Mithun S                   14
# Mukesh                      3
# Muskan Garg                12
# Nandani Gupta              11
# Nishtha Jain               18
# Nitin M                     1
# ...

# %%
#Total working days for each agents 
df.groupby('Agent')['Date'].nunique()
# Out:
# Agent
# Aditya Shinde              1
# Aditya_iot                 8
# Amersh                     2
# Ameya Jain                 7
# Ankitjha                   2
# Anurag Tiwari             10
# Aravind                    7
# Ayushi Mishra              9
# Bharath                    8
# Boktiar Ahmed Bappy        9
# Chaitra K Hiremath         7
# Deepranjan Gupta          10
# Dibyanshu                  9
# Harikrishnan Shaji         9
# Hrisikesh Neogi            9
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            11
# Jawala Prakash             9
# Jaydeep Dixit              7
# Khushboo Priya             8
# Madhulika G                8
# Mahesh Sarade              8
# Maitry                     5
# Manjunatha A               7
# Mithun S                   8
# Mukesh                     2
# Muskan Garg                6
# Nandani Gupta              9
# Nishtha Jain               8
# Nitin M                    1
# Prabir Kumar Satapathy     7
# ...

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2[df2['Agent Name']=='Aditya Shinde'][["Total Feedback", "Agent Name"]]
# Out:
#       Total Feedback     Agent Name
# 26                 0  Aditya Shinde
# 102                0  Aditya Shinde
# 173                0  Aditya Shinde
# 249                0  Aditya Shinde
# 318                0  Aditya Shinde
# 390                0  Aditya Shinde
# 460                0  Aditya Shinde
# 531                0  Aditya Shinde
# 607                0  Aditya Shinde
# 674                0  Aditya Shinde
# 752                0  Aditya Shinde
# 819                0  Aditya Shinde
# 892                0  Aditya Shinde
# 961                0  Aditya Shinde
# 1023              15  Aditya Shinde
# 1095               8  Aditya Shinde
# 1182               0  Aditya Shinde
# 1246               9  Aditya Shinde
# 1310               9  Aditya Shinde
# 1389              15  Aditya Shinde
# 1464               0  Aditya Shinde
# 1528              14  Aditya Shinde
# 1600               7  Aditya Shinde
# 1689               0  Aditya Shinde
# 1744              11  Aditya Shinde
# ...

# %%
df2[df2['Agent Name']=='Aditya Shinde']["Total Chats"].sum()
# Out:
# 277

# %%
#Total query that you hvae taken 
df3 = df2.groupby(['Agent Name'])["Total Chats"].sum()

# %%
print(df3)
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
# total Feedback that you have received 
df4 = df2.groupby(['Agent Name'])["Total Feedback"].sum()

# %%
print(df4)
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
dtype(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [273], in <cell line: 1>()
# ----> 1 dtype(df2)
#
# NameError: name 'dtype' is not defined

# %%
df2.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df2['Date'] = pd.to_datetime(df['Date'])

# %%
df2.dtypes
# Out:
# SL No                               int64
# Date                       datetime64[ns]
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# dtype: object

# %%
df7 = df2['Date'].dt.week
# Out:
# C:\Users\DJParni\AppData\Local\Temp\ipykernel_37528\1066475416.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df7 = df2['Date'].dt.week

# %%
df7
# Out:
# 0       30.0
# 1       30.0
# 2       30.0
# 3       30.0
# 4       30.0
#         ...
# 2155     NaN
# 2156     NaN
# 2157     NaN
# 2158     NaN
# 2159     NaN
# Name: Date, Length: 2160, dtype: float64

# %%
df6 = df2.groupby(['Agent Name',df7])['Average Response Time']

# %%
for each in df6:
    print (each)
# Out:
# (('Abhishek ', 29.0), 616    0:00:00
# 683    0:00:00
# 761    0:00:00
# 830    0:00:00
# 901    0:00:00
# 972    0:00:00
# Name: Average Response Time, dtype: object)
# (('Abhishek ', 30.0), 34     0:00:00
# 109    0:00:00
# 181    0:00:00
# 256    0:00:00
# 325    0:00:00
# 397    0:00:00
# 470    0:00:00
# 541    0:00:00
# Name: Average Response Time, dtype: object)
# (('Aditya ', 29.0), 620    0:00:00
# 690    0:00:00
# 765    0:00:00
# 834    0:00:00
# 907    0:00:00
# 977    0:00:00
# Name: Average Response Time, dtype: object)
# (('Aditya ', 30.0), 43     0:00:00
# 117    0:00:00
# 188    0:00:00
# 262    0:00:00
# 332    0:00:00
# 403    0:00:00
# 476    0:00:00
# 547    0:00:00
# Name: Average Response Time, dtype: object)
# (('Aditya Shinde', 29.0), 607    0:00:00
# 674    0:00:00
# 752    0:00:00
# 819    0:00:00
# 892    0:00:00
# 961    0:00:00
# Name: Average Response Time, dtype: object)
# (('Aditya Shinde', 30.0), 26     0:00:00
# 102    0:00:00
# 173    0:00:00
# ...

# %%
agent_response = agent_data[(agent_data["Total_Chats"] != 0)][["Agent_Name","Average_Response_Time","week"]]
agent_response = agent_response[agent_response["Agent_Name"] == "Prerna Singh"]
agent_response = agent_response["Average_Response_Time"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 agent_response = agent_data[(agent_data["Total_Chats"] != 0)][["Agent_Name","Average_Response_Time","week"]]
#       2 agent_response = agent_response[agent_response["Agent_Name"] == "Prerna Singh"]
#       3 agent_response = agent_response["Average_Response_Time"]
#
# NameError: name 'agent_data' is not defined
